# %%
# %%capture
# !pip install import-ipynb 
# !pip install --upgrade google-generativeai

# %%
# %%capture
import import_ipynb
import google.generativeai as genai
from emotional_tone import generate_emotion  # Assumes emotional-tone.ipynb has function definitions
from causal_inference import get_causal_inference
from theme_extraction import extract_theme
from entity_relations import extract_entities_relationships
import json

# %%
test_text = """
                One thing we’ve learned from the COVID-19 crisis is how important Amazon has become to our customers. We
want you to know we take this responsibility seriously, and we’re proud of the work our teams are doing to help
customers through this difficult time.
Amazonians are working around the clock to get necessary supplies delivered directly to the doorsteps of people
who need them. The demand we are seeing for essential products has been and remains high. But unlike a
predictable holiday surge, this spike occurred with little warning, creating major challenges for our suppliers and
delivery network. We quickly prioritized the stocking and delivery of essential household staples, medical
supplies, and other critical products.
Our Whole Foods Market stores have remained open, providing fresh food and other vital goods for customers.
We are taking steps to help those most vulnerable to the virus, setting aside the first hour of shopping at Whole
Foods each day for seniors. We have temporarily closed Amazon Books, Amazon 4-star, and Amazon Pop Up
stores because they don’t sell essential products, and we offered associates from those closed stores the
opportunity to continue working in other parts of Amazon.
Crucially, while providing these essential services, we are focused on the safety of our employees and contractors
around the world—we are deeply grateful for their heroic work and are committed to their health and well-being.
Consulting closely with medical experts and health authorities, we’ve made over 150 significant process changes
in our operations network and Whole Foods Market stores to help teams stay healthy, and we conduct daily
audits of the measures we’ve put into place. We’ve distributed face masks and implemented temperature checks
at sites around the world to help protect employees and support staff. We regularly sanitize door handles,
stairway handrails, lockers, elevator buttons, and touch screens, and disinfectant wipes and hand sanitizer are
standard across our network.
We’ve also introduced extensive social distancing measures to help protect our associates. We have eliminated
stand-up meetings during shifts, moved information sharing to bulletin boards, staggered break times, and spread
out chairs in breakrooms. While training new hires is challenging with new distancing requirements, we continue
to ensure that every new employee gets six hours of safety training. We’ve shifted training protocols so we don’t
have employees gathering in one spot, and we’ve adjusted our hiring processes to allow for social distancing.
A next step in protecting our employees might be regular testing of all Amazonians, including those showing no
symptoms. Regular testing on a global scale, across all industries, would both help keep people safe and help get
the economy back up and running. For this to work, we as a society would need vastly more testing capacity than
is currently available. If every person could be tested regularly, it would make a huge difference in how we fight
this virus. Those who test positive could be quarantined and cared for, and everyone who tests negative could
re-enter the economy with confidence.
We’ve begun the work of building incremental testing capacity. A team of Amazonians—from research scientists
and program managers to procurement specialists and software engineers—moved from their normal day jobs
onto a dedicated team to work on this initiative. We have begun assembling the equipment we need to build our
first lab and hope to start testing small numbers of our frontline employees soon. We are not sure how far we will
get in the relevant timeframe, but we think it’s worth trying, and we stand ready to share anything we learn.
While we explore longer-term solutions, we are also committed to helping support employees now. We increased
our minimum wage through the end of April by $2 per hour in the U.S., $2 per hour in Canada, £2 per hour in the
UK, and €2 per hour in many European countries. And we are paying associates double our regular rate for any
overtime worked—a minimum of $34 an hour—an increase from time and a half. These wage increases will cost
more than $500 million, just through the end of April, and likely more than that over time. While we recognize
this is expensive, we believe it’s the right thing to do under the circumstances. We also established the Amazon
Relief Fund—with an initial $25 million in funding—to support our independent delivery service partners and
their drivers, Amazon Flex participants, and temporary employees under financial distress.
In March, we opened 100,000 new positions across our fulfillment and delivery network. Earlier this week, after
successfully filling those roles, we announced we were creating another 75,000 jobs to respond to customer
demand. These new hires are helping customers who depend on us to meet their critical needs. We know that
many people around the world have suffered financially as jobs are lost or furloughed. We are happy to have
them on our teams until things return to normal and either their former employer can bring them back or new
jobs become available. We’ve welcomed Joe Duffy, who joined after losing his job as a mechanic at Newark
airport and learned about an opening from a friend who is an Amazon operations analyst. Dallas preschool
teacher Darby Griffin joined after her school closed on March 9th and now helps manage new inventory. We’re
happy to have Darby with us until she can return to the classroom.
Amazon is acting aggressively to protect our customers from bad actors looking to exploit the crisis. We’ve
removed over half a million offers from our stores due to COVID-based price gouging, and we’ve suspended
more than 6,000 selling accounts globally for violating our fair-pricing policies. Amazon turned over information
about sellers we suspect engaged in price gouging of products related to COVID-19 to 42 state attorneys general
offices. To accelerate our response to price-gouging incidents, we created a special communication channel for
state attorneys general to quickly and easily escalate consumer complaints to us.
Amazon Web Services is also playing an important role in this crisis. The ability for organizations to access
scalable, dependable, and highly secure computing power—whether for vital healthcare work, to help students
continue learning, or to keep unprecedented numbers of employees online and productive from home—is critical
in this situation. Hospital networks, pharmaceutical companies, and research labs are using AWS to care for
patients, explore treatments, and mitigate the impacts of COVID-19 in many other ways. Academic institutions
around the world are transitioning from in-person to virtual classrooms and are running on AWS to help ensure
continuity of learning. And governments are leveraging AWS as a secure platform to build out new capabilities
in their efforts to end this pandemic.
We are collaborating with the World Health Organization, supplying advanced cloud technologies and technical
expertise to track the virus, understand the outbreak, and better contain its spread. WHO is leveraging our cloud
to build large-scale data lakes, aggregate epidemiological country data, rapidly translate medical training videos
into different languages, and help global healthcare workers better treat patients. We are separately making a
public AWS COVID-19 data lake available as a centralized repository for up-to-date and curated information
related to the spread and characteristics of the virus and its associated illness so experts can access and analyze
the latest data in their battle against the disease.
We also launched the AWS Diagnostic Development Initiative, a program to support customers working to bring
more accurate diagnostic solutions to market for COVID-19. Better diagnostics help accelerate treatment and
containment of this pandemic. We committed $20 million to accelerate this work and help our customers harness
the cloud to tackle this challenge. While the program was established in response to COVID-19, we also are
looking toward the future, and we will fund diagnostic research projects that have the potential to blunt future
infectious disease outbreaks.
            """
            
te_result = extract_theme(test_text)
ci_result = get_causal_inference(test_text)
er_result = extract_entities_relationships(test_text)

# %%
print(json.dumps(te_result, indent=4))  # Pretty-print the output JSON
print(json.dumps(ci_result, indent=4))
# Out:
# {
#     "themes": [
#         {
#             "name": "Employee Safety and Support",
#             "importance": "10",
#             "subthemes": [
#                 {
#                     "name": "Process Changes for Safety",
#                     "importance": "9"
#                 },
#                 {
#                     "name": "Wage Increases and Overtime Pay",
#                     "importance": "8"
#                 },
#                 {
#                     "name": "Amazon Relief Fund",
#                     "importance": "7"
#                 },
#                 {
#                     "name": "Potential Employee Testing",
#                     "importance": "8"
#                 }
#             ]
#         },
#         {
#             "name": "Meeting Customer Demand During Crisis",
#             "importance": "9",
#             "subthemes": [
#                 {
#                     "name": "Prioritizing Essential Products",
#                     "importance": "9"
#                 },
#                 {
#                     "name": "New Job Creation",
#                     "importance": "8"
#                 }
#             ]
#         },
#         {
#             "name": "Combating Price Gouging",
#             "importance": "8",
#             "subthemes": [
#                 {
#                     "name": "Removing Inflated Offers",
#                     "importance": "8"
#                 },
#                 {
#                     "name": "Suspending Seller Accounts",
#                     "importance": "7"
#                 },
#                 {
#                     "name": "Collaboration with Attorneys General",
#                     "importance": "7"
#                 }
#             ]
#         },
#         {
#             "name": "AWS Support for COVID-19 Response",
#             "importance": "9",
#             "subthemes": [
#                 {
#                     "name": "Supporting Healthcare, Education, and Government",
#                     "importance": "9"
#                 },
#                 {
#                     "name": "Collaboration with WHO",
#                     "importance": "8"
#                 },
#                 {
#                     "name": "AWS Diagnostic Development Initiative",
#                     "importance": "8"
#                 }
#             ]
#         },
#         {
#             "name": "Maintaining Essential Services",
#             "importance": "8",
#             "subthemes": [
#                 {
#                     "name": "Keeping Whole Foods Open",
#                     "importance": "8"
#                 },
#                 {
#                     "name": "Adjustments to Store Operations",
#                     "importance": "7"
#                 }
#             ]
#         }
#     ]
# }
# {
#     "causal_relations": [
#         {
#             "cause": "COVID-19 crisis",
#             "effect": "Increased importance of Amazon to customers",
#             "confidence": 8,
#             "proof": "One thing we\u2019ve learned from the COVID-19 crisis is how important Amazon has become to our customers."
#         },
#         {
#             "cause": "Spike in demand for essential products with little warning",
#             "effect": "Major challenges for suppliers and delivery network",
#             "confidence": 9,
#             "proof": "But unlike a predictable holiday surge, this spike occurred with little warning, creating major challenges for our suppliers and delivery network."
#         },
#         {
#             "cause": "Vulnerability to the virus (seniors)",
#             "effect": "Setting aside the first hour of shopping at Whole Foods each day for seniors.",
#             "confidence": 9,
#             "proof": "We are taking steps to help those most vulnerable to the virus, setting aside the first hour of shopping at Whole Foods each day for seniors."
#         },
#         {
#             "cause": "Stores don\u2019t sell essential products",
#             "effect": "Temporary closure of Amazon Books, Amazon 4-star, and Amazon Pop Up stores.",
#             "confidence": 9,
#             "proof": "We have temporarily closed Amazon Books, Amazon 4-star, and Amazon Pop Up stores because they don\u2019t sell essential products"
#         },
#         {
#             "cause": "Consulting closely with medical experts and health authorities",
#             "effect": "Made over 150 significant process changes in our operations network and Whole Foods Market stores.",
#             "confidence": 8,
#             "proof": "Consulting closely with medical experts and health authorities, we\u2019ve made over 150 significant process changes in our operations network and Whole Foods Market stores to help teams stay healthy"
#         },
#         {
#             "cause": "New distancing requirements",
#             "effect": "Challenges with training new hires",
#             "confidence": 7,
#             "proof": "While training new hires is challenging with new distancing requirements"
#         },
#         {
#             "cause": "Increased wage",
#             "effect": "Wage increases will cost more than $500 million",
#             "confidence": 8,
#             "proof": "We increased our minimum wage... These wage increases will cost more than $500 million"
#         },
#         {
#             "cause": "Jobs are lost or furloughed",
#             "effect": "Many people around the world have suffered financially",
#             "confidence": 9,
#             "proof": "We know that many people around the world have suffered financially as jobs are lost or furloughed."
#         },
#         {
#             "cause": "COVID-based price gouging",
#             "effect": "Removed over half a million offers from our stores.",
#             "confidence": 9,
#             "proof": "We\u2019ve removed over half a million offers from our stores due to COVID-based price gouging"
#         },
#         {
#             "cause": "Need to track the virus",
#             "effect": "Amazon collaborated with the World Health Organization (WHO), supplying advanced cloud technologies and technical expertise.",
#             "confidence": 8,
#             "proof": "We are collaborating with the World Health Organization, supplying advanced cloud technologies and technical expertise to track the virus"
#         }
#     ]
# }

# %%
# Initialize node and edge lists
nodes = []
edges = []

# Helper function to check if a node already exists
def add_node(node_id, node_type, importance=0.5):
    if not any(node["id"] == node_id for node in nodes):
        nodes.append({"id": node_id, "type": node_type, "importance": importance})

# Extract nodes from themes and subthemes
for theme in te_result["themes"]:
    add_node(theme["name"], "theme", theme["importance"])
    
    # Extract subthemes as nodes and create edges connecting them to their parent themes
    for subtheme in theme.get("subthemes", []):
        add_node(subtheme["name"], "subtheme", subtheme["importance"])
        edges.append({
            "source": theme["name"],
            "target": subtheme["name"],
            "name": "parent theme of",
            "type": "thematic",
            "importance": subtheme["importance"]  # Default weight for theme-subtheme relationships
        })

# Extract edges from entity relationships
for entity in er_result["entities"]:
    add_node(entity["name"], entity["type"], entity["importance"])

# Extract edges from relationships
for relation in er_result["relationships"]:
    edges.append({
        "source": relation["subject"],
        "target": relation["object"],
        "name": relation["relation"],
        "type": "correlated",
        "importance": 5  # Default weight, you can modify this based on confidence if available
    })


print(nodes)
# Out:
# [{'id': 'Employee Safety and Support', 'type': 'theme', 'importance': '10'}, {'id': 'Process Changes for Safety', 'type': 'subtheme', 'importance': '9'}, {'id': 'Wage Increases and Overtime Pay', 'type': 'subtheme', 'importance': '8'}, {'id': 'Amazon Relief Fund', 'type': 'subtheme', 'importance': '7'}, {'id': 'Potential Employee Testing', 'type': 'subtheme', 'importance': '8'}, {'id': 'Meeting Customer Demand During Crisis', 'type': 'theme', 'importance': '9'}, {'id': 'Prioritizing Essential Products', 'type': 'subtheme', 'importance': '9'}, {'id': 'New Job Creation', 'type': 'subtheme', 'importance': '8'}, {'id': 'Combating Price Gouging', 'type': 'theme', 'importance': '8'}, {'id': 'Removing Inflated Offers', 'type': 'subtheme', 'importance': '8'}, {'id': 'Suspending Seller Accounts', 'type': 'subtheme', 'importance': '7'}, {'id': 'Collaboration with Attorneys General', 'type': 'subtheme', 'importance': '7'}, {'id': 'AWS Support for COVID-19 Response', 'type': 'theme', 'importance': '9'}, {'id': 'Supporting Healthcare, Education, and Government', 'type': 'subtheme', 'importance': '9'}, {'id': 'Collaboration with WHO', 'type': 'subtheme', 'importance': '8'}, {'id': 'AWS Diagnostic Development Initiative', 'type': 'subtheme', 'importance': '8'}, {'id': 'Maintaining Essential Services', 'type': 'theme', 'importance': '8'}, {'id': 'Keeping Whole Foods Open', 'type': 'subtheme', 'importance': '8'}, {'id': 'Adjustments to Store Operations', 'type': 'subtheme', 'importance': '7'}, {'id': 'Amazon', 'type': 'Company', 'importance': '10'}, {'id': 'Amazonians', 'type': 'Employee', 'importance': '9'}, {'id': 'Whole Foods Market', 'type': 'Company', 'importance': '8'}, {'id': 'Amazon Books', 'type': 'Company', 'importance': '5'}, {'id': 'Amazon 4-star', 'type': 'Company', 'importance': '5'}, {'id': 'Amazon Pop Up', 'type': 'Company', 'importance': '5'}, {'id': 'Joe Duffy', 'type': 'Person', 'importance': '3'}, {'id': 'Darby Griffin', 'type': 'Person', 'importance': '3'}, {'id': 'Amazon Web Services (AWS)', 'type': 'Company', 'importance': '8'}, {'id': 'World Health Organization (WHO)', 'type': 'Organization', 'importance': '7'}, {'id': 'State Attorneys General', 'type': 'Group', 'importance': '6'}, {'id': 'Independent Delivery Service Partners', 'type': 'Group', 'importance': '6'}, {'id': 'Amazon Flex', 'type': 'Organization', 'importance': '6'}]

# %%
from sentence_transformers import SentenceTransformer, util
from fuzzywuzzy import fuzz

def semantic_match(query, node_data, threshold=0.4):
    """Matches query to nodes based on semantic similarity."""
    model = SentenceTransformer('all-MiniLM-L6-v2')
    query_embedding = model.encode(query, convert_to_tensor=True)
    matches = []
    for node in node_data: #access nodes from the dictionary.
        node_id = node["id"]
        node_embedding = model.encode(node_id, convert_to_tensor=True)
        similarity = util.cos_sim(query_embedding, node_embedding).item()
        if similarity > threshold:
            matches.append((node_id, similarity))
    sorted_matches = sorted(matches, key=lambda item: item[1], reverse=True)
    return sorted_matches

# def fuzzy_match(query, node_data, threshold=70):
#     """Matches query to nodes based on fuzzy string matching."""
#     matches = []
#     for node in node_data: #access nodes from the dictionary.
#         node_id = node["id"]
#         similarity = fuzz.ratio(query, node_id)
#         if similarity > threshold:
#             matches.append((node_id, similarity))
#     return matches

# def contextual_match(query, context, node_data):
#     """Matches query to nodes based on keywords found in the context."""
#     matches = []
#     query_words = query.lower().split()
#     context_lower = context.lower()
#     for node in node_data: #access nodes from the dictionary.
#         node_id = node["id"].lower()
#         if node_id in context_lower or any(word in context_lower for word in node_id.split()):
#             matches.append(node["id"])
#     return matches

# def combined_match(query, context, node_data, semantic_threshold=0.4, fuzzy_threshold=70):
#     """Combines semantic, fuzzy, and contextual matching."""
#     semantic_matches = semantic_match(query, node_data, semantic_threshold)
#     fuzzy_matches = fuzzy_match(query, node_data, fuzzy_threshold)
#     contextual_matches = contextual_match(query, context, node_data)

#     all_matches = {}

#     for node_id, score in semantic_matches:
#         all_matches[node_id] = all_matches.get(node_id, 0) + score

#     for node_id, score in fuzzy_matches:
#         all_matches[node_id] = all_matches.get(node_id, 0) + (score/100)

#     for node_id in contextual_matches:
#         all_matches[node_id] = all_matches.get(node_id, 0) + 1

#     sorted_matches = sorted(all_matches.items(), key=lambda item: item[1], reverse=True)
#     return sorted_matches

def process_cause_effect(cause_effect_data, node_data):
    """Processes cause and effect data to find matching nodes using only semantic matching."""
    cause_node = None
    effect_node = None

    cause_matches = semantic_match(cause_effect_data["cause"], node_data)
    effect_matches = semantic_match(cause_effect_data["effect"], node_data)

    # print(f"Cause Matches: {cause_matches}")
    # print(f"Effect Matches: {effect_matches}")

    if cause_matches:
        cause_node = cause_matches[0][0]  # Get the top match
    if effect_matches:
        effect_node = effect_matches[0][0]  # Get the top match

    return cause_node, effect_node


# def process_cause_effect(cause_effect_data, node_data, context=""):
#     """Processes cause and effect data to find matching nodes."""
#     cause_node = None
#     effect_node = None

#     cause_matches = combined_match(cause_effect_data["cause"], context, node_data)
#     effect_matches = combined_match(cause_effect_data["effect"], context, node_data)
    
#     print(cause_matches)
#     print(effect_matches)

#     if cause_matches:
#         cause_node = cause_matches[0][0]  # Get the top match
#     if effect_matches:
#         effect_node = effect_matches[0][0] # Get the top match

#     return cause_node, effect_node
# Out:
# WARNING:tensorflow:From c:\Python312\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
# c:\Python312\Lib\site-packages\fuzzywuzzy\fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
# Extract edges from causal inference
for relation in ci_result["causal_relations"]:
    
    cause_node, effect_node = process_cause_effect(relation, nodes)
    # print(f"Cause Node: {cause_node}, Effect Node: {effect_node}\n")
    if cause_node is not None and effect_node is not None:
        edges.append({
            "source": cause_node,
            "target": effect_node,
            "name": relation["proof"],
            "type": "causal",
            "importance": relation["confidence"]
        })

print(edges)
# Out:
# [{'source': 'Employee Safety and Support', 'target': 'Process Changes for Safety', 'name': 'parent theme of', 'type': 'thematic', 'importance': '9'}, {'source': 'Employee Safety and Support', 'target': 'Wage Increases and Overtime Pay', 'name': 'parent theme of', 'type': 'thematic', 'importance': '8'}, {'source': 'Employee Safety and Support', 'target': 'Amazon Relief Fund', 'name': 'parent theme of', 'type': 'thematic', 'importance': '7'}, {'source': 'Employee Safety and Support', 'target': 'Potential Employee Testing', 'name': 'parent theme of', 'type': 'thematic', 'importance': '8'}, {'source': 'Meeting Customer Demand During Crisis', 'target': 'Prioritizing Essential Products', 'name': 'parent theme of', 'type': 'thematic', 'importance': '9'}, {'source': 'Meeting Customer Demand During Crisis', 'target': 'New Job Creation', 'name': 'parent theme of', 'type': 'thematic', 'importance': '8'}, {'source': 'Combating Price Gouging', 'target': 'Removing Inflated Offers', 'name': 'parent theme of', 'type': 'thematic', 'importance': '8'}, {'source': 'Combating Price Gouging', 'target': 'Suspending Seller Accounts', 'name': 'parent theme of', 'type': 'thematic', 'importance': '7'}, {'source': 'Combating Price Gouging', 'target': 'Collaboration with Attorneys General', 'name': 'parent theme of', 'type': 'thematic', 'importance': '7'}, {'source': 'AWS Support for COVID-19 Response', 'target': 'Supporting Healthcare, Education, and Government', 'name': 'parent theme of', 'type': 'thematic', 'importance': '9'}, {'source': 'AWS Support for COVID-19 Response', 'target': 'Collaboration with WHO', 'name': 'parent theme of', 'type': 'thematic', 'importance': '8'}, {'source': 'AWS Support for COVID-19 Response', 'target': 'AWS Diagnostic Development Initiative', 'name': 'parent theme of', 'type': 'thematic', 'importance': '8'}, {'source': 'Maintaining Essential Services', 'target': 'Keeping Whole Foods Open', 'name': 'parent theme of', 'type': 'thematic', 'importance': '8'}, {'source': 'Maintaining Essential Services', 'target': 'Adjustments to Store Operations', 'name': 'parent theme of', 'type': 'thematic', 'importance': '7'}, {'source': 'Amazonians', 'target': 'Amazon', 'name': 'works at', 'type': 'correlated', 'importance': 5}, {'source': 'Whole Foods Market', 'target': 'Amazon', 'name': 'is a subsidiary of', 'type': 'correlated', 'importance': 5}, {'source': 'Amazon Books', 'target': 'Amazon', 'name': 'is a part of', 'type': 'correlated', 'importance': 5}, {'source': 'Amazon 4-star', 'target': 'Amazon', 'name': 'is a part of', 'type': 'correlated', 'importance': 5}, {'source': 'Amazon Pop Up', 'target': 'Amazon', 'name': 'is a part of', 'type': 'correlated', 'importance': 5}, {'source': 'Joe Duffy', 'target': 'Amazon', 'name': 'works at', 'type': 'correlated', 'importance': 5}, {'source': 'Darby Griffin', 'target': 'Amazon', 'name': 'works at', 'type': 'correlated', 'importance': 5}, {'source': 'Amazon Web Services (AWS)', 'target': 'Amazon', 'name': 'is a part of', 'type': 'correlated', 'importance': 5}, {'source': 'World Health Organization (WHO)', 'target': 'Amazon', 'name': 'collaborates with', 'type': 'correlated', 'importance': 5}, {'source': 'State Attorneys General', 'target': 'Amazon', 'name': 'communicates with', 'type': 'correlated', 'importance': 5}, {'source': 'Amazon Relief Fund', 'target': 'Amazon', 'name': 'supported by', 'type': 'correlated', 'importance': 5}, {'source': 'Independent Delivery Service Partners', 'target': 'Amazon', 'name': 'works with', 'type': 'correlated', 'importance': 5}, {'source': 'Amazon Flex', 'target': 'Amazon', 'name': 'works with', 'type': 'correlated', 'importance': 5}, {'source': 'AWS Support for COVID-19 Response', 'target': 'Amazon Web Services (AWS)', 'name': 'One thing we’ve learned from the COVID-19 crisis is how important Amazon has become to our customers.', 'type': 'causal', 'importance': 8}, {'source': 'Prioritizing Essential Products', 'target': 'Independent Delivery Service Partner ...

# %%
# Combine everything into final JSON format
graph_json = {
    "nodes": nodes,
    "edges": edges
}

# Save to a JSON file
with open("narrative_genome.json", "w") as f:
    json.dump(graph_json, f, indent=4)

# Print output for verification
print(json.dumps(graph_json, indent=4))
# Out:
# {
#     "nodes": [
#         {
#             "id": "Employee Safety and Support",
#             "type": "theme",
#             "importance": "10"
#         },
#         {
#             "id": "Process Changes for Safety",
#             "type": "subtheme",
#             "importance": "9"
#         },
#         {
#             "id": "Wage Increases and Overtime Pay",
#             "type": "subtheme",
#             "importance": "8"
#         },
#         {
#             "id": "Amazon Relief Fund",
#             "type": "subtheme",
#             "importance": "7"
#         },
#         {
#             "id": "Potential Employee Testing",
#             "type": "subtheme",
#             "importance": "8"
#         },
#         {
#             "id": "Meeting Customer Demand During Crisis",
#             "type": "theme",
#             "importance": "9"
#         },
#         {
#             "id": "Prioritizing Essential Products",
#             "type": "subtheme",
#             "importance": "9"
#         },
#         {
#             "id": "New Job Creation",
#             "type": "subtheme",
#             "importance": "8"
#         },
#         {
#             "id": "Combating Price Gouging",
#             "type": "theme",
#             "importance": "8"
#         },
#         {
#             "id": "Removing Inflated Offers",
#             "type": "subtheme",
#             "importance": "8"
#         },
#         {
#             "id": "Suspending Seller Accounts",
#             "type": "subtheme",
#             "importance": "7"
#         },
#         {
#             "id": "Collaboration with Attorneys General",
#             "type": "subtheme",
#             "importance": "7"
#         },
#         {
#             "id": "AWS Support for COVID-19 Response",
#             "type": "theme",
#             "importance": "9"
#         },
#         {
#             "id": "Supporting Healthcare, Education, and Government",
#             "type": "subtheme",
#             "importance": "9"
#         },
#         {
#             "id": "Collaboration with WHO",
#             "type": "subtheme",
#             "importance": "8"
#         },
#         {
#             "id": "AWS Diagnostic Development Initiative",
#             "type": "subtheme",
#             "importance": "8"
#         },
#         {
#             "id": "Maintaining Essential Services",
#             "type": "theme",
#             "importance": "8"
#         },
#         {
#             "id": "Keeping Whole Foods Open",
#             "type": "subtheme",
#             "importance": "8"
#         },
#         {
#             "id": "Adjustments to Store Operations",
#             "type": "subtheme",
#             "importance": "7"
#         },
#         {
#             "id": "Amazon",
#             "type": "Company",
#             "importance": "10"
#         },
#         {
#             "id": "Amazonians",
#             "type": "Employee",
#             "importance": "9"
#         },
#         {
#             "id": "Whole Foods Market",
#             "type": "Company",
#             "importance": "8"
#         },
#         {
#             "id": "Amazon Books",
#             "type": "Company",
#             "importance": "5"
#         },
#         {
#             "id": "Amazon 4-star",
#             "type": "Company",
#             "importance": "5"
#         },
#         {
#             "id": "Amazon Pop Up",
#             "type": "Company",
#             "importance": "5"
#         },
#         {
#             "id": "Joe Duffy",
#             "type": "Person",
#             "importance": "3"
#         },
#         {
#             "id": "Darby Griffin",
#             "type": "Person",
#             "importance": "3"
#         },
#         {
#             "id": "Amazon Web Services (AWS)",
#             "type": "Company",
#             "importance": "8"
#         },
#         {
#             "id": "World Health Organization (WHO)",
#             "type": "Organization",
#             "importance": "7"
#         },
#         {
#             "id": "State Attorneys General",
#             "type": "Group",
#             "importance": "6"
#         },
#         {
#             "id": "Independent Delivery Service Partners",
#             "type": "Group",
#             "importance": "6"
#         },
#         {
#             "id": "Amazon Flex",
#             "type": "Organization",
#             "importance": "6"
#         }
#     ],
#     "edges": [
#         {
#             "source": "Employee Safety and Support",
#             "target": "Process Changes for Safety",
#             "name": "parent theme of",
#             "type": "thematic",
#             "importance": "9"
#         },
#         {
#             "source": "Employee Safety and Support",
#             "target": "Wage Increases and Overtime Pay",
#             "name": "parent theme of",
#             "type": "thematic",
#             "importance": "8"
#         },
#         {
#             "source": "Employee Safety and Support",
#             "target": "Amazon Relief Fund",
#             "name": "parent theme of",
#             "type": "thematic",
#             "importance": "7"
#         },
#         {
#             "source": "Employee Safety and Support",
#             "target": "Potential Employee Testing",
#             "name": "parent theme of",
#             "type": "thematic",
#             "importance": "8"
#         },
#         {
#             "source": "Meeting Customer Demand During Crisis",
#             "target": "Prioritizing Essential Products",
#             "name": "parent theme of",
#             "type": "thematic",
#             "importance": "9"
#         },
#         {
#             "source": "Meeting Customer Demand During Crisis",
#             "target": "New Job Creation",
#             "name": "parent theme of",
#             "type": "thematic",
#             "importance": "8"
#         },
#         {
#             "source": "Combating Price Gouging",
#             "target": "Removing Inflated Offers",
#             "name": "parent theme of",
#             "type": "thematic",
#             "importance": "8"
#         },
#         {
#             "source": "Combating Price Gouging",
#             "target": "Suspending Seller Accounts",
#             "name": "parent theme of",
#             "type": "thematic",
#             "importance": "7"
#         },
#         {
#             "source": "Combating Price Gouging",
#             "target": "Collaboration with Attorneys General",
#             "name": "parent theme of",
#             "type": "thematic",
#             "importance": "7"
#         },
#         {
#             "source": "AWS Support for COVID-19 Response",
#             "target": "Supporting Healthcare, Education, and Government",
#             "name": "parent theme of",
#             "type": "thematic",
#             "importance": "9"
#         },
#         {
#             "source": "AWS Support for COVID-19 Response",
#             "target": "Collaboration with WHO",
#             "name": "parent theme of",
#             "type": "thematic",
#             "importance": "8"
#         },
#         {
#             "source": "AWS Support for COVID-19 Response",
#             "target": "AWS Diagnostic Development Initiative",
#             "name": "parent theme of",
#             "type": "thematic",
#             "importance": "8"
#         },
#         {
#             "source": "Maintaining Essential Services",
#             "target": "Keeping Whole Foods Open",
#             "name": "parent theme of",
#             "type": "thematic",
#             "importance": "8"
#         },
#         {
#             "source": "Maintaining Essential Services",
#             "target": "Adjustments to Store Operations",
#             "name": "parent theme of",
#             "type": "thematic",
#             "importance": "7"
#         },
#         {
#             "source": "Amazonians",
#             "target": "Amazon",
#             "name": "works at",
#             "type": "correlated",
#             "importance": 5
#         },
#         {
#             "source": "Whole Foods Market",
#             "target": "Amazon",
#             "name": "is a subsidiary of",
#             "type": "correlated",
#             "importance": 5
#         },
#         {
#             "source": "Amazon Books",
#             "target": "Amazon",
#             "name": "is a part of",
#             "type": "correlated",
#             "importance": 5
#         },
#         {
#             "source": "Amazon 4-star",
#             "target": "Amazon",
#             "name": "is a part of",
#             "type": "correlated",
#             "importance": 5
#         },
#         {
#             "source": "Amazon Pop Up",
#             "target": "Amazon",
#             "name": "is a part of",
#             "type": "correlated",
#             "importance": 5
#         },
#         {
#             "source": "Joe Duffy",
#             "target": "Amazon",
#             "name": "works at",
#             "type": "correlated",
#             "importance": 5
#         },
#         {
#             "source": "Darby Griffin",
#             "target": "Amazon",
#             "name": "works at",
#             "type": "correlated",
#             "importance": 5
#         },
#         {
#             "source": "Amazon Web Services (AWS)",
#             "target": "Amazon",
#             "name": "is a part of",
#             "type": "correlated",
#             "importance": 5
#         },
#         {
#             "source": "World Health Organization (WHO)",
#             "target": "Amazon",
#             "name": "collaborates with",
#             "type": "correlated",
#             "importance": 5
#         },
#         {
#             "source": "State Attorneys General",
#             "target": "Amazon",
#             "name": "communicates with",
#             "type": "correlated",
#             "importance": 5
#         },
#         {
#             "source": "Amazon Relief Fund",
#             "target": "Amazon",
#             "name": "supported by",
#             "type": "correlated",
#             "importance": 5
#         },
#         {
#             "source": "Independent Delivery Service Partners",
#             "target": "Amazon",
#             "name": "works with",
#             "type": "correlated",
#             "importance": 5
#         },
#         {
#             "source": "Amazon Flex",
#             "target": "Amazon",
#             "name": "works with",
#             "type": "correlated",
#             "importance": 5
#         },
#         {
#             "source": "AWS Support for COVID-19 Response",
#             "target": "Amazon Web Services (AWS)",
#             "name": "One thing we\u2019ve learned from the COVID-19 crisis is how important Amazon has become to our customers.",
#             "type": "causal",
#             "importance": 8
#         },
#         {
#             "source": "Prioritizing Essential Products",
#             "target": "Independent Delivery Service Partners",
#             "name": "But unlike a predictable holiday surge, this spike occurred with little warning, creating major challenges for our suppliers and delivery network.",
#             "type": "causal",
#             "importance": 9
#         },
#         {
#             "source": "Prioritizing Essential Products",
#             "target": "Amazon Books",
#             "name": "We have temporarily closed Amazon Books, Amazon 4-star, and Amazon Pop Up stores because they don\u2019t sell essential products",
#             "type": "causal",
#             "importance": 9
#         },
#         {
#             "source": "World Health Organization (WHO)",
#             "target": "Whole Foods Market",
#             "name": "Consulting closely with medical experts and health authorities, we\u2019ve made over 150 significant process changes in our operations network and Whole Foods Market stores to help teams stay healthy",
#             "type": "causal",
#             "importance": 8
#         },
#         {
#             "source": "Wage Increases and Overtime Pay",
#             "target": "Wage Increases and Overtime Pay",
#             "name": "We increased our minimum wage... These wage increases will cost more than $500 million",
#             "type": "causal",
#             "importance": 8
#         },
#         {
#             "source": "Combating Price Gouging",
#             "target": "Removing Inflated Offers",
#             "name": "We\u2019ve removed over half a million offers from our stores due to COVID-based price gouging",
#             "type": "causal",
#             "importance": 9
#         }
#     ]
# }
